# %%
# Import the machine learning libraries.
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
from keras.layers import Dense,GlobalAveragePooling2D
from keras.applications import MobileNet
from keras.applications.mobilenet import preprocess_input
import numpy as np
from IPython.display import Image
from keras.optimizers import Adam

# %% [markdown]
# ###Load MobileNet

# %%
# MobileNet paper: https://arxiv.org/pdf/1704.04861.pdf
mobile = keras.applications.mobilenet.MobileNet()
# Out:
# ...
# 17227776/17225924 [==============================] - 0s 0us/step

# %%
def prepare_image(file):
    img_path = ''
    img = image.load_img(img_path + file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
Image(filename='/content/drive/MyDrive/ML_Code/MobileNet/strawberry.jpg')

# %%
preprocessed_image = prepare_image('/content/drive/MyDrive/ML_Code/MobileNet/strawberry.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n07745940', 'strawberry', 0.98845834),
#   ('n03991062', 'pot', 0.0075856782),
#   ('n12620546', 'hip', 0.0011545238),
#   ('n07749582', 'lemon', 0.00078120624),
#   ('n07760859', 'custard_apple', 0.00038986644)]]

# %%
Image(filename='/content/drive/MyDrive/ML_Code/MobileNet/doberman.jpg')

# %%
preprocessed_image = prepare_image('/content/drive/MyDrive/ML_Code/MobileNet/doberman.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n02107142', 'Doberman', 0.9715721),
#   ('n02107312', 'miniature_pinscher', 0.026243055),
#   ('n02106550', 'Rottweiler', 0.0005464981),
#   ('n02087046', 'toy_terrier', 0.0003140038),
#   ('n02097130', 'giant_schnauzer', 0.0002717046)]]

# %%
Image(filename='/content/drive/MyDrive/ML_Code/MobileNet/chameleon.jpg')

# %%
preprocessed_image = prepare_image('/content/drive/MyDrive/ML_Code/MobileNet/chameleon.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n01694178', 'African_chameleon', 0.9999491),
#   ('n01693334', 'green_lizard', 1.8363826e-05),
#   ('n01689811', 'alligator_lizard', 1.1925867e-05),
#   ('n01675722', 'banded_gecko', 5.901491e-06),
#   ('n01682714', 'American_chameleon', 5.878641e-06)]]
